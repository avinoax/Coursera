# %% [markdown]
# ##Data
#
# As highlighted in my previous report, we're going to be focusing on the Northern Virginia area. The data set attached is from Zillow.com and is broken out by neighborhood. For this project, I am only using a small subset to illustrate the process. The data compares rent prices for 6 months and whether they're increasing or decreasing for the top neighborhoods in Northern Virginia. Additionally, we will use foursquare data to look at ratings of nearby restaurants. For this project, we're going to be comparing Italian restaurants.

# %%
import pandas as pd
url='https://raw.githubusercontent.com/avinoax/Coursera/master/VADataset.csv'
readfile = pd.read_csv(url)
readfile.head(13)
# Out:
#          NeighborhoodName            City State           CountyName  2019-01  \
# 0           Dover Crystal       Arlington    VA     Arlington County     4721
# 1                Woodmont       Arlington    VA     Arlington County     4186
# 2     Chain Bridge Forest       Arlington    VA     Arlington County     3979
# 3          Dominion Hills       Arlington    VA     Arlington County     3445
# 4           Madison Manor       Arlington    VA     Arlington County     3251
# 5         Boulevard Manor       Arlington    VA     Arlington County     3243
# 6                Yorktown       Arlington    VA     Arlington County     3147
# 7           The North End  Virginia Beach    VA  Virginia Beach City     3102
# 8   Cape Story by the Sea  Virginia Beach    VA  Virginia Beach City     3059
# 9           Croatan Beach  Virginia Beach    VA  Virginia Beach City     3034
# 10         Arlington View       Arlington    VA     Arlington County     2959
# 11        Stonewall Court        Richmond    VA        Richmond City     2842
# 12              Northeast      Alexandria    VA      Alexandria City     2687
#
#     2019-02  2019-03  2019-04  2019-05  2019-06
# 0      4717     4738     4680     4718     4761
# 1      4217     4257     4253     4293     4326
# 2      3889     3785     3752     3778     3864
# 3      3388     3387     3427     3494     3528
# 4      3250     3290     3344     3379     3397
# 5      3271     3264     3229     3247     3296
# 6      3148     3128     3052     3062     3071
# 7      3200     3226     3264     3267     3253
# 8      3088     3114     3142     3172     3172
# 9      3090     3118     3135     2910     2957
# 10     2960     3000     3097     3148     3176
# 11     2868     2869     2901     2933     2943
# 12     2700     2734     2754     2775     2792

# %% [markdown]
# #### How to use the data:
# As explained in the previous report, we need to evaulate rental prices and ratings of surrounding restuarants in the area to determine a final output score. It's important to note that I am just using a sample data set to illustrate the underlying process to the project. The process itself can be rerun to evaulate and compare neighborhood  "scores".
#
# To calculate an overall score for each neighborhood we're going to be giving rent a score and restaurant rating a score with a weight. The closer the score is to 1, the better rating that overall location is.
#
# Location score formula: Score= (rentscore).3+(ratingscore).7
#
# Rentscore Formula: (MaxNeighborhoodrent-averagerentofneighborhood)/(maxrentofneighborhood-minrentofneighborhood). Use the data set above to calculate rent score.
#
# Ratingscore: (maxrating-restaurantrating)/(maxrating-minrating). Use the foursquare location data below to find rating of restaurant.

# %% [markdown]
# ## Below we are obtaining the coorindates of the neighborhoods.

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
address = 'Dover Crystal, Arlington, VA'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Latitude and longitude of '+address+' are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# Latitude and longitude of Dover Crystal, Arlington, VA are 38.9067782, -77.1058118.

# %% [markdown]
# We now have the coorindates so we need to cross reference that with Foursquare to get all the restaurants in that area.

# %% [markdown]
# ###### Foursquare Credentials inserted here

# %%
categoryId= '4bf58dd8d48988d110941735'   #categoryID for Italian restaurant.
radius=3000                              # radius in meters

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius,
    categoryId)

# %%
#Send the GET request and examine the resutls
import requests 
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d726edc6e4650002c2bce55'},
#  'response': {'venues': [{'id': '5ad689466fa81f1ef7170614',
#     'name': 'Lupo Verde Osteria',
#     'location': {'address': '4814 MacArthur Blvd NW',
#      'lat': 38.91676083930262,
#      'lng': -77.0963966846466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91676083930262,
#        'lng': -77.0963966846466}],
#      'distance': 1378,
#      'postalCode': '20007',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['4814 MacArthur Blvd NW',
#       'Washington, D.C. 20007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '4b6b0763f964a520b6ed2be3',
#     'name': 'Cafe Tirolo',
#     'location': {'address': '4001 Fairfax Dr',
#      'lat': 38.882868002249104,
#      'lng': -77.10858967886338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.882868002249104,
#        'lng': -77.10858967886338}],
#      'distance': 2672,
#      'postalCode': '22203',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['4001 Fairfax Dr',
#       'Arlington, VA 22203',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '469254d5f964a520cc481fe3',
#     'name': 'Faccia Luna Arlington',
#     'location': {'address': '2909 Wilson Blvd',
#      'lat': 38.88863613587681,
#      'lng': -77.09363400936127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.88863613587681,
#        'lng': -77.09363400936127}],
#      'distance': 2278,
#      'postalCode': '22201',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['2909 Wilson Blvd',
#       'Arlington, VA 22201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '87103882'},
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '4b1b1904f964a5200af823e3',
#     'name': 'Il Radicchio',
#     'location': {'address': '1801 Clarendon Blvd',
#      'lat': 38.89269040097503,
#      'lng': -77.08003298859221,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89269040097503,
#        'lng': -77.08003298859221}],
#      'distance': 2728,
#      'postalCode': '22201',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1801 Clarendon Blvd',
#       'Arlington, VA 22201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '82944803'},
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '4d7bcbf0136bf04d8ffe528d',
#     'name': "Pete's New Haven Style Apizza",
#     'location': {'address': '3017 Clarendon Blvd',
#      'crossStreet': 'at Garfield St',
#      'lat': 38.8874419358066,
#      'lng': -77.09442257881165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8874419358066,
#        'lng': -77.09442257881165}],
#      'distance': 2367,
#      'postalCode': '22201',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['3017 Clarendon Blvd (at Garfield St)',
#       'Arlington, VA 22201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '58e7cf85fc5a5f12cac21532',
#     'name': '7th Hill Pizza',
#     'location': {'address': '4885 MacArthur Blvd NW',
#      'lat': 38.917855,
#      'lng': -77.096886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.917855,
#        'lng': -77.096886}],
#      'distance': 1455,
#      'postalCode': '20007',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['4885 MacArthur Blvd NW',
#       'Washington, D.C. 20007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '56215102498e6d66765f415a',
#     'name': 'Fillmore Pizza',
#     'location': {'address': '5175 Lee Hwy',
#      'crossStreet': 'N George Mason Drive',
#      'lat': 38.896397444790786,
#      'lng': -77.13330641835965,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.896397444790786,
#        'lng': -77.13330641835965}],
#      'distance': 2647,
#      'postalCode': '22207',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['5175 Lee Hwy (N George Mason Drive)',
#       'Arlington, VA 22207',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '315199',
#      'url': 'https://www.grubhub.com/restaurant/fillmore-pizza-5175-lee-hwy-arlington/315199?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=315199',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1567780572',
#     'hasPerk': False},
#    {'id': '4b0b3798f964a520d82e23e3',
#     'name': "Ruffino's Spaghetti House",
#     'location': {'address': '4763 Lee Hwy',
#      'crossStreet': 'at Glebe Rd.',
#      'lat': 38.89749194976414,
#      'lng': -77.12419482474576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89749194976414,
#        'lng': -77.12419482474576}],
#      'distance': 1898,
#      'postalCode': '22207',
#      'cc': 'US',
#      'city': 'Arlington',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['4763 Lee Hwy (at Glebe Rd.)',
#       'Arlington, VA 22207',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '69125',
#      'url': 'https://www.grubhub.com/restaurant/ruffinos-spaghetti-house-4763-lee-hwy-arlington/69125?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=69125',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1567780572',
#     'hasPerk': False}],
#   'confident': True}}

# %% [markdown]
# ### Restaurant details above have been extracted. We need to now check how many there are within a 3000 meter radius using a json response.

# %%
Restaurants= len(results['response']['venues'])
print ('There are',  Restaurants , 'restaurants.')
# Out:
# There are 8 restaurants.

# %% [markdown]
# ### Now we extract venue id for first restaurant with a rating

# %%
venueid= results['response']['venues'][3]['id']
venueid
# Out:
# '4b1b1904f964a5200af823e3'

# %% [markdown]
# ### Now we extract venueID venue details

# %%
url2 = 'https://api.foursquare.com/v2/venues/4b1b1904f964a5200af823e3?&client_id={}&client_secret={}&v={}&ll={},{}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude
    )
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5d7271c48ad62e0039c6dcd0'},
#  'response': {'venue': {'id': '4b1b1904f964a5200af823e3',
#    'name': 'Il Radicchio',
#    'contact': {'phone': '7032762627',
#     'formattedPhone': '(703) 276-2627',
#     'twitter': 'ilradicchio'},
#    'location': {'address': '1801 Clarendon Blvd',
#     'lat': 38.89269040097503,
#     'lng': -77.08003298859221,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 38.89269040097503,
#       'lng': -77.08003298859221}],
#     'distance': 2728,
#     'postalCode': '22201',
#     'cc': 'US',
#     'city': 'Arlington',
#     'state': 'VA',
#     'country': 'United States',
#     'formattedAddress': ['1801 Clarendon Blvd',
#      'Arlington, VA 22201',
#      'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/il-radicchio/4b1b1904f964a5200af823e3',
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': True,
#    'stats': {'tipCount': 13},
#    'url': 'http://ilradicchio.com',
#    'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#    'hasMenu': True,
#    'likes': {'count': 20,
#     'groups': [{'type': 'others', 'count': 20, 'items': []}],
#     'summary': '20 Likes'},
#    'dislike': False,
#    'ok': False,
#    'rating': 7.5,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 37,
#    'menu': {'type': 'Menu',
#     'label': 'Menu',
#     'anchor': 'View Menu',
#     'url': 'https://foursquare.com/v/il-radicchio/4b1b1904f964a5200af823e3/menu',
#     'mobileUrl': 'https://foursquare.com/v/4b1b1904f964a5200af823e3/device_menu'},
#    'allowMenuUrlEdit': True,
#    'beenHere': {'count': 0,
#     'unconfirmedCount': 0,
#     'marked': False,
#     'lastCheckinExpiredAt': 0},
#    'specials': {'count': 0, 'items': []},
#    'photos': {'count': 34,
#     'groups': [{'type': 'checkin',
#       'name': "Friends' check-in photos",
#       'count': 0,
#       'items': []},
#      {'type': 'venue',
#       'name': 'Venue photos',
#       'count': 34,
#       'items': [{'id': '508c7c8ce4b01167eb46e3fb',
#         'createdAt': 1351384204,
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'https://foursquare.com/download/#/iphone'},
#         'prefix': 'https://fastly.4sqi.net/img/general/',
#         'suffix': '/2721077_w7PanVttNqcHow1cEmmdtwXg0SCHEEhy89Ra0L7QmSU.jpg',
#         'width': 720,
#         'height': 537,
#         'user': {'id': '2721077',
#          'firstName': 'Derrick',
#          'lastName': 'Thomas',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/CSMC1E4D2EBLUNOX.jpg'}},
#         'visibility': 'public'}]}],
#     'summary': '0 photos'},
#    'venuePage': {'id': '82944803'},
#    'reasons': {'count': 0, 'items': []},
#    'page': {'user': {'id': '82944803',
#      'firstName': 'Il Radicchio',
#      'gender': 'none',
#      'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#       'suffix': '/82944803-OTVJXDIH22MB1JO5.png'},
#      'type': 'venuePage',
#      'venue': {'id': '4b1b1904f964a5200af823e3'},
#      'tips': {'count': 0},
#      'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#      'homeCity': 'Arlington, VA',
#      'bio': '',
#      'contact': {}}},
#    'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#    'createdAt': 1260067076,
#    'tips': {'count': 13,
#     'groups': [{'type': 'others',
#       'name': 'All tips',
#       'count': 13,
#       'items': [{'id': '52f65ce9498e76f0925a5683',
#         'createdAt': 1391877353,
#         'text': 'Pistachio cream sauce is amazing. Come split a bottle of wine and enjoy the pasta.',
#         'type': 'user',
#         'canonicalUrl': 'https://foursquare.com/item/52f65ce9498e76f0925a5683',
#         'lang': 'en',
#         'likes': {'count': 3,
#          'groups': [{'type': 'others',
#            'count': 3,
#            'items': [{'id': '2451400',
#              'firstName': 'Hector',
#              'lastName': 'Collado',
#              'gender': 'male',
#              'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#               'suffix': '/QAMTWCJOYA2RKFFL.jpg'}},
#             {'id': '2654773',
#              'firstName': 'John',
#              'lastName': 'K',
#              'gender': 'male',
#              'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#               'suffix': '/514NTBFC05P5HMXI.jpg'}}]}],
#          'summary': '3 likes'},
#         'logView': True,
#         'agreeCount': 3,
#         'disagreeCount': 0,
#         'todo': {'count': 0},
#         'user': {'id': '11559476',
#          'firstName': 'Amanda',
#          'lastName': 'Culp',
#          'gender': 'female',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/0K3ILU5JUU3AOXGX.jpg'}}}]}]},
#    'shortUrl': 'http://4sq.com/dh2Iu9',
#    'timeZone': 'America/New_York',
#    'listed': {'count': 10,
#     'groups': [{'type': 'others',
#       'name': 'Lists from other people',
#       'count': 10,
#       'items': [{'id': '55c3fd84498e5fde9c199725',
#         'name': 'Virginia is for ❤️',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '134007237',
#          'firstName': 'Kelly',
#          'lastName': 'Madigan',
#          'gender': 'female',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/134007237-B412HVBRUI01BUNY.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/134007237/list/virginia-is-for-',
#         'canonicalUrl': 'https://foursquare.com/user/134007237/list/virginia-is-for-',
#         'createdAt': 1438907780,
#         'updatedAt': 1449272481,
#         'photo': {'id': '557485a0498ed07fd489bc6b',
#          'createdAt': 1433699744,
#          'prefix': 'https://fastly.4sqi.net/img/general/',
#          'suffix': '/13462349_x4lvsSyt2_MuAkuwGoknghoCJUgXQvaApZH43LS1hc4.jpg',
#          'width': 640,
#          'height': 640,
#          'user': {'id': '13462349',
#           'firstName': 'saleh',
#           'gender': 'male',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/LXB3KVKMR3FUH133.jpg'}},
#          'visibility': 'public'},
#         'followers': {'count': 0},
#         'listItems': {'count': 6,
#          'items': [{'id': 'v4b1b1904f964a5200af823e3',
#            'createdAt': 1444697768}]}},
#        {'id': '5100c5a0e4b0ae12a8098631',
#         'name': 'Food',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '20682791',
#          'firstName': 'J',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/20682791-G1KFVKAHGHGIJEQJ.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/20682791/list/food',
#         'canonicalUrl': 'https://foursquare.com/user/20682791/list/food',
#         'createdAt': 1359005088,
#         'updatedAt': 1397686000,
#         'followers': {'count': 1},
#         'listItems': {'count': 158,
#          'items': [{'id': 'v4b1b1904f964a5200af823e3',
#            'createdAt': 1366752818}]}},
#        {'id': '5180794de4b00aea40d1cf61',
#         'name': 'VA',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '20682791',
#          'firstName': 'J',
#          'gender': 'male',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/20682791-G1KFVKAHGHGIJEQJ.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/20682791/list/va',
#         'canonicalUrl': 'https://foursquare.com/user/20682791/list/va',
#         'createdAt': 1367374157,
#         'updatedAt': 1373234926,
#         'followers': {'count': 0},
#         'listItems': {'count': 40,
#          'items': [{'id': 'v4b1b1904f964a5200af823e3',
#            'createdAt': 1369532848}]}},
#        {'id': '52c4979a11d2dba4a8de8d18',
#         'name': 'DC',
#         'description': '',
#         'type': 'others',
#         'user': {'id': '20689079',
#          'firstName': 'Mollie',
#          'lastName': 'Bloudoff',
#          'gender': 'none',
#          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#           'suffix': '/20689079-FIDHG1UOKWVFWJKI.jpg'}},
#         'editable': False,
#         'public': True,
#         'collaborative': False,
#         'url': '/user/20689079/list/dc',
#         'canonicalUrl': 'https://foursquare.com/user/20689079/list/dc',
#         'createdAt': 1388615578,
#         'updatedAt': 1482553494,
#         'followers': {'count': 0},
#         'listItems': {'count': 26,
#          'items': [{'id': 'v4b1b1904f964a5200af823e3',
#            'createdAt': 1400476129}]}}]}]},
#    'hours': {'status': 'Closed until Noon',
#     'richStatus': {'entities': [], 'text': 'Closed until Noon'},
#     'isOpen': False,
#     'isLocalHoliday': False,
#     'dayData': [],
#     'timeframes': [{'days': 'Mon–Sat',
#       'includesToday': True,
#       'open': [{'renderedTime': 'Noon–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'popular': {'isOpen': False,
#     'isLocalHoliday': False,
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': '5:00 PM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': '6:00 PM–7:00 PM'}],
#       'segments': []},
#      {'days': 'Tue',
#       'open': [{'renderedTime': '6:00 PM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Wed',
#       'open': [{'renderedTime': '5:00 PM–9:00 PM'}],
#       'segments': []},
#      {'days': 'Thu',
#       'open': [{'renderedTime': '6:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'pageUpdates': {'count': 0, 'items': []},
#    'inbox': {'count': 0, 'items': []},
#    'attributes': {'groups': [{'type': 'price',
#       'name': 'Price',
#       'summary': '$$',
#       'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$',
#         'priceTier': 2}]},
#      {'type': 'payments',
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. Discover & Visa)'}]},
#      {'type': 'outdoorSeating',
#       'name': 'Outdoor Seating',
#       'summary': 'Outdoor Seating',
#       'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#      {'type': 'serves',
#       'name': 'Menus',
#       'summary': 'Dinner',
#       'count': 8,
#       'items': [{'displayName': 'Dinner', 'displayValue': 'Dinner'}]}]},
#    'bestPhoto': {'id': '508c7c8ce4b01167eb46e3fb',
#     'createdAt': 1351384204,
#     'source': {'name': 'Foursquare for iOS',
#      'url': 'https://foursquare.com/download/#/iphone'},
#     'prefix': 'https://fastly.4sqi.net/img/general/',
#     'suffix': '/2721077_w7PanVttNqcHow1cEmmdtwXg0SCHEEhy89Ra0L7QmSU.jpg',
#     'width': 720,
#     'height': 537,
#     'visibility': 'public'},
#    'colors': {'highlightColor': {'photoId': '508c7c8ce4b01167eb46e3fb',
#      'value': -10471416},
#     'highlightTextColor': {'photoId': '508c7c8ce4b01167eb46e3fb', 'value': -1},
#     'algoVersion': 3}}}}

# %%
restaurantrating = results2['response']['venue']['rating']
restaurantrating
# Out:
# 7.5

# %% [markdown]
# ## You repeat the same process for every neighborhood to obtain the rating value then calculate your the score of the neighborhood using the formula mentioned above
